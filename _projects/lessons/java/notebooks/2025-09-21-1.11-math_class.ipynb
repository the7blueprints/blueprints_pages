// %% [raw]
// ---
// layout: post
// categories: [Java, Math-Class]
// lesson_language: Java
// lesson_topic: Math-Class
// lesson_part: interactive
// lesson_source: APCSA
// assignment: true
// title: 1.11 Math Class
// menu: nav/csa_units/csaunit1.html
// permalink: /csa/unit_01/1_11
// author: Gurshawn, Anvay, Akshay (Bridget)
// ---

// %% [markdown]
// ##  The Problem: Building a Game Without Math Class
//
// Imagine you're creating a simple RPG game and you need to:
// - Calculate a player's damage: 10 × (1.5<sup>level</sup>)
// - Find the distance between the player and an enemy
// - Generate random loot drops
// - Round numbers for displaying stats

// %% [markdown]
// ## Quick Reference
//
// * `Math` is in `java.lang`, so no import is needed.
// * The `Math` class contains **static methods**, so call them with `Math.methodName()`.
// * `Math.abs(x)` → absolute value.
// * `Math.pow(base, exponent)` → power.
// * `Math.sqrt(x)` → nonnegative square root.
// * `Math.random()` → a `double` from **0.0 inclusive to 1.0 exclusive**.
// * Random values can be changed with arithmetic and casting to make a defined range.

// %% [markdown]
// ## Lesson Plan
//
// **Objective:** Use built-in Math class methods in expressions and determine the values they produce.
//
// **Success Criteria:** Given a Math method call, identify what it returns and use it correctly in a Java expression.
//
// ### What is the Math Class?
//
// The `Math` class is part of `java.lang`, which is available automatically. Its methods are static, so we call them with `Math.methodName()`.
//
// ### College Board Essential Knowledge
//
// | Method | What it does | Example |
// | :--- | :--- | :--- |
// | `Math.abs(int)` / `Math.abs(double)` | Absolute value | `Math.abs(-5)` → `5` |
// | `Math.pow(double, double)` | Raises a number to a power | `Math.pow(2, 3)` → `8.0` |
// | `Math.sqrt(double)` | Nonnegative square root | `Math.sqrt(25)` → `5.0` |
// | `Math.random()` | Random `double` from 0.0 inclusive to 1.0 exclusive | `Math.random()` → varies |

// %% [markdown]
// ### Examples
//
// ```java
// System.out.println(Math.abs(-12));       // 12
// System.out.println(Math.pow(2, 3));      // 8.0
// System.out.println(Math.sqrt(25));       // 5.0
// System.out.println(Math.random());       // 0.0 <= value < 1.0
// ```
//
// You can combine Math methods in an expression:
//
// ```java
// double distance = Math.sqrt(Math.pow(3, 2) + Math.pow(4, 2));
// System.out.println(distance); // 5.0
// ```

// %%
public class MathDemo {
    public static void main(String[] args) {
        System.out.println(Math.abs(-12));
        System.out.println(Math.pow(2, 3));
        System.out.println(Math.sqrt(25));
        System.out.println(Math.random());
    }
}

// %% [markdown]
// ## The Important Part: `Math.random()`
//
// `Math.random()` gives a `double` such that:
//
// ```text
// 0.0 <= Math.random() < 1.0
// ```
//
// To get a random **integer from `min` to `max`, inclusive**:
//
// ```java
// (int)(Math.random() * (max - min + 1)) + min
// ```
//
// Example: a number from 1 through 6:
//
// ```java
// int roll = (int)(Math.random() * 6) + 1;
// ```
//
// Why?
//
// 1. `Math.random()` gives `0.0` up to but not including `1.0`.
// 2. Multiplying by `6` gives `0.0` up to but not including `6.0`.
// 3. Casting to `int` gives `0` through `5`.
// 4. Adding `1` gives `1` through `6`.

// %% [markdown]
// ## Practice
//
// **Popcorn Hack #1 (2 min):** Without running the code, determine the output.
//
// ```java
// System.out.println(Math.abs(-8));
// System.out.println(Math.pow(3, 2));
// System.out.println(Math.sqrt(36));
// ```
//
// Then write one `Math` expression that calculates the distance between `(0, 0)` and `(3, 4)`.
//
// **Popcorn Hack #2:** Create a program that generates a random integer from **10 through 20**, inclusive.
//
// Hint:
//
// ```java
// (int)(Math.random() * (max - min + 1)) + min
// ```

// %% [markdown]
// ## Homework Hack: Random Loot
//
// Create a simple loot drop program.
//
// ### Requirements
//
// - Generate a random rarity number from **1–100**.
// - `1–60` → Common
// - `61–85` → Rare
// - `86–100` → Legendary
// - Generate a random gold value:
//   - Common: `10–30`
//   - Rare: `31–70`
//   - Legendary: `71–100`
// - Print the rarity roll, rarity, and gold value.
//
// You must use `Math.random()` to generate the random values.
//
// ### Example Output
//
// ```text
// Loot Drop!
// Rarity Roll: 73
// You got: RARE item
// Gold Value: 54
// ```
//
// The exact output will change each time because the values are random.

// %% [markdown]
// ## Quick Summary - What You Learned
//
// ### Key Methods to Remember
//
// 1. **`Math.abs(x)`** — absolute value
// 2. **`Math.pow(base, exponent)`** — powers
// 3. **`Math.sqrt(x)`** — square roots
// 4. **`Math.random()`** — random `double` from 0.0 inclusive to 1.0 exclusive
//
// ### Important Formula
//
// ```java
// (int)(Math.random() * (max - min + 1)) + min
// ```
//
// This produces a random integer from `min` through `max`, inclusive.

// %% [markdown]
// ## Homework Checklist
//
// ### What to Submit:
//
// 1. Completed Random Loot program.
// 2. Evidence that the program runs.
//
// ### Before You Submit:
//
// - Your rarity is between 1 and 100.
// - Your gold value stays within the correct range.
// - You used `Math.random()`.
// - You tested the program more than once.

// %% [markdown]
// ## Grading Rubric — 1 Point
//
// | Criteria | Points |
// | :--- | ---: |
// | Popcorn Hacks attempted | 0.2 |
// | Correct use of `Math` methods | 0.3 |
// | Random ranges work correctly | 0.3 |
// | Program runs and produces the required output | 0.2 |
// | **Total** | **1.0** |
//
// ## Revisions
//
// * **Feedback:** [Math class is relatively simple, the concept of basic math functions is easy to learn quickly and doesn't need so many words to explain these simple concepts, examples are less straightforward and need to be more clear cut.]
// * **Change made:** [Shortened lesson significantly and reduced useless jargon and text that wasn't necessary to basically and concisely explain the math class, revised popcorn hacks to fit AI grading.]

// %% [markdown]
// ---
//
// ## LxD Cycle: Math Class
//
// **Empathize — student learning issues:** Students commonly expect `Math` to require an object or import, overlook that `pow` and `sqrt` return `double`, and treat `Math.random()` as if it could return `1.0`. Random-integer expressions create additional trouble when students cast before multiplying, omit the `+ 1` needed for an inclusive range, or cannot explain which endpoints are possible.
//
// **Define:**
// - **POV:** Students need to reason from each `Math` method's return type and range because memorizing a random-number formula does not reveal off-by-one or misplaced-cast errors.
// - **Learning issue:** Students need to trace scaling, casting, and shifting as separate transformations of the interval `0.0 <= value < 1.0`.
//
// **Ideate:**
// - **HMW Question:** How might we turn a random-range expression into visible interval transformations rather than a formula to copy?
// - **HMW Question:** How might repeated trials help students detect an impossible endpoint without suggesting that a short test proves correctness?
// - **Activity:** Annotate the range after each operation in `(int)(Math.random() * 6) + 1`, repair two off-by-one variants, and compare observed rolls with the mathematically possible set.
//
// **Prototype & Test:** Ask a partner to build a range from 10 through 20 and justify both endpoints before running it. Record where the interval reasoning breaks, then revise the diagram or prompt and test again.
//
// ### College Board and Academic Connections
//
// For Topic 1.11, the College Board specifies that `Math` "contains only class methods" (College Board, 2025, p. 44) and describes manipulating `Math.random()` results with arithmetic and casts to make defined ranges. Oracle's Java SE 25 API documents `Math` as the standard class for basic numeric operations and specifies the contracts for `abs`, `pow`, `sqrt`, and `random`, so predictions should be based on those return values and ranges (Oracle, 2025).
//
// ## References
//
// College Board. (2025). *AP Computer Science A course and exam description* [Effective fall 2025]. https://apcentral.collegeboard.org/media/pdf/ap-computer-science-a-course-and-exam-description-effective-fall-2025.pdf
//
// Oracle. (2025). *Math (Java SE 25 & JDK 25)* [API documentation]. https://docs.oracle.com/en/java/javase/25/docs/api/java.base/java/lang/Math.html

// %% [markdown]
// [past homework]({{site.baseurl}}/csa/unit_01/1_11_hw)
