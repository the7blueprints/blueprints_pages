# %% [raw]
# ---
# layout: post
# codemirror: true
# categories: [Java, Classes-and-Objects]
# lesson_language: Java
# lesson_topic: Classes-and-Objects
# lesson_source: APCSA
# lesson_type: lesson
# assignment: true
# title: 1.12 Classes & Objects
# description: Understand that objects are instances of classes with data and methods.
# menu: nav/csa_units/csaunit1.html
# permalink: /csa/unit_01/1_12
# author: Kush, Trevor, Elliot, Aranya, Travis, Alex, Bridget
# ---

# %% [markdown]
# ## References
#
# College Board. (2025). *AP Computer Science A course and exam description* [Effective fall 2025]. https://apcentral.collegeboard.org/media/pdf/ap-computer-science-a-course-and-exam-description-effective-fall-2025.pdf
#
# Gosling, J., Joy, B., Steele, G., Bracha, G., Buckley, A., Smith, D., & Bierman, G. (2025). *The Java language specification: Java SE 25 edition* (Secs. 4.3.1–4.3.2). Oracle. https://docs.oracle.com/javase/specs/jls/se25/html/jls-4.html#jls-4.3.1

# %% [markdown]
# ## Quick Reference
#
# * **Class** = blueprint/template for objects.
# * **Object** = one instance created from a class.
# * `new` creates an object and gives you a **reference** to it.
# * A reference variable points to an object; it does not contain a separate copy.
# * `Object` is the superclass of every Java class.

# %% [markdown]
# ## LxD Cycle: Classes, Objects, and References
#
# **Empathize — student learning issues:** Students often treat a class, an object, and a reference variable as three names for the same thing. The blueprint analogy can also suggest that assigning `d2 = d1` builds a second object, so students are surprised when a change through `d2` is visible through `d1`. The capitalization difference between an object in general and Java's `Object` class can create another misconception.
#
# **Define:**
# - **POV:** Students need a model that separates the class definition, the runtime object, and each reference variable because code syntax alone does not show aliasing.
# - **Learning issue:** Students need to trace reference assignment as copying a reference value, not copying the object's fields.
#
# **Ideate:**
# - **HMW Question:** How might we draw references so two variables pointing to one object cannot be mistaken for two objects?
# - **HMW Question:** How might we distinguish the general word *object* from the Java class `Object` while keeping their relationship clear?
# - **Activity:** Draw a box-and-arrow memory model for `Dog d1 = new Dog(); Dog d2 = d1;`, predict the result of changing `d2.name`, and then verify the prediction in code.
#
# **Prototype & Test:** Ask a partner to update the diagram after each statement without running the program. Compare the final prediction with the output and revise any symbol that encouraged the partner to invent an extra object.
#
# ### College Board and Academic Connections
#
# For Topic 1.12, the College Board defines an object as a "specific instance of a class" (College Board, 2025, p. 45) and explains that a reference variable holds an object reference. The Java Language Specification similarly distinguishes an object from the reference values that point to it and identifies `Object` as the superclass of all other classes (Gosling et al., 2025, §§4.3.1–4.3.2).

# %% [markdown]
# ## Lesson Plan
#
# **Objective:** Understand the difference between classes and objects, how reference variables work, and why every Java class inherits from `Object`.
#
# **Success Criteria:** Given a class and object example, identify the class, object, and reference variable.
#
# ### Class vs. Object
#
# A **class** is a blueprint. An **object** is a specific instance made from that blueprint.
#
# ### Examples
#
# ```java
# class Dog {
#     String name;
#     int age;
#
#     void bark() {
#         System.out.println(name + " says woof!");
#     }
# }
#
# Dog myDog = new Dog();
# myDog.name = "Alo";
# myDog.age = 3;
# myDog.bark();
# ```
#
# `Dog` is the class. `myDog` is a reference variable pointing to a `Dog` object.

# %% [markdown]
# ## Reference Variables
#
# Two reference variables can point to the **same object**.
#
# ```java
# Dog d1 = new Dog();
# d1.name = "Kai";
#
# Dog d2 = d1;
# d2.name = "Kairo";
#
# System.out.println(d1.name); // Kairo
# ```
#
# `d2 = d1` does **not** create a copy. Both variables refer to the same `Dog` object.
#
# ## `Object`
#
# Every Java class ultimately extends `Object`.
#
# That means objects have methods such as:
#
# * `toString()`
# * `equals(Object)`
# * `getClass()`
#
# ```java
# Dog x = new Dog();
# System.out.println(x.getClass().getName());
# System.out.println(x instanceof Object); // true
# ```

# %% [markdown]
# ## Practice
#
# **Popcorn Hack (2 min):** Complete the code.
#
# 1. Finish `Book` by adding `printInfo()`.
# 2. Create one `Book` object, set its fields, and call `printInfo()`.
#
# ```java
# class Book {
#     String title;
#     int pages;
#
#     // TODO: write printInfo()
# }
#
# public class MainPopcorn {
#     public static void main(String[] args) {
#         // TODO: make one Book, set its fields, and call printInfo()
#     }
# }
# ```

# %% [markdown]
# ## Homework Checklist
#
# ### What to Submit:
#
# 1. Completed Popcorn Hack.
# 2. Evidence that the program runs.
#
# ### Before You Submit:
#
# - You created a class and an object.
# - You used `new`.
# - You understand that two references can point to the same object.
# - You can name one method inherited from `Object`.

# %% [markdown]
# ## Grading Rubric — 1 Point
#
# | Criteria | Points |
# | :--- | ---: |
# | Popcorn Hack attempted | 0.3 |
# | Correct class/object usage | 0.3 |
# | Correct understanding of references | 0.2 |
# | Program runs | 0.2 |
# | **Total** | **1.0** |

# %% [markdown]
# [past homework]({{site.baseurl}}/csa/unit_01/1_12/homework)
