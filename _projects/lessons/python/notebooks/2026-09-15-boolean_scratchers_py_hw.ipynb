# %% [raw]
# ---
# layout: post
# categories: [Python, Boolean-Expressions]
# lesson_language: Python
# lesson_topic: Boolean-Expressions
# lesson_source: APCSP
# lesson_type: lesson
# codemirror: true
# microblog: true
# assignment: true
# assignment_name: 3.05 Boolean Expressions - SFI Backend
# toc: false
# comments: false
# title: 3.05 Boolean Expressions
# description: Learn Boolean expressions in Python using the five-part LxD lesson format.
# permalink: /python/boolean
# ---

# %% [markdown]
# A **Boolean expression** is a question that evaluates to only `True` or `False`. Python is the main language for this lesson. The examples use SFI Foundation automotive specification data so the Tech Talks and Popcorn Hacks stay in one consistent backend theme.
#
# ## 1. LxD Cycle Process
#
# **Empathize:** Boolean expressions can look simple, but it is easy to mix up `and` and `or`, forget a boundary such as `>=`, or write a condition that does not match the rule in normal English.
#
# **Define:**
# - **POV:** CSP students need a clear way to turn real-world rules into Boolean expressions so their programs make the correct decisions.
# - **Learning Goal:** Students will be able to evaluate, write, test, and explain Boolean expressions in Python.
#
# **Ideate:**
# - **HMW Question:** How might we make Boolean logic easier to understand before students have to write a full program?
# - **Activity:** Predict Boolean results, fix an incorrect condition, and then build one complete decision checker.
#
# **Prototype & Test:** Use the SFI Tech Talks and Popcorn Hacks below to check whether students can predict results before running code, choose the correct Boolean operator, and explain why their expression matches the backend rule.
#
# ---
#
# ## 2. Lesson Plan
#
# **Learning Objective:** By the end of this lesson, you will be able to use comparisons, `and`, `or`, and `not` to create Boolean expressions and use them in Python decisions.
#
# **Success Criteria:** You can predict whether an expression is `True` or `False`, write a condition from a rule in normal English, and test the condition with more than one set of values.
#
# ### Tech Talk 1: Comparisons Create Booleans
#
# SFI backend records contain values such as product names, categories, spec numbers, and record counts. Comparison operators turn checks on those values into `True` or `False`.
#
# | Python | Meaning | SFI example |
# | --- | --- | --- |
# | `==` | equal to | `spec_number == "1.1"` |
# | `!=` | not equal to | `category != "Street Car"` |
# | `>` | greater than | `part_count > 0` |
# | `<` | less than | `part_count < 100` |
# | `>=` | greater than or equal to | `part_count >= 1` |
# | `<=` | less than or equal to | `part_count <= 100` |

# %%
# CODE_RUNNER: Tech Talk 1 - Compare SFI Part Data

spec_number = "1.1"
category = "Auto Racing"
part_count = 12

print("Spec is 1.1:", spec_number == "1.1")
print("Category is not Street Car:", category != "Street Car")
print("At least one part record exists:", part_count >= 1)

# %% [markdown]
# Remember:
# - `spec_number = "1.1"` assigns a value.
# - `spec_number == "1.1"` compares two values.
#
# ### Tech Talk 2: `and`, `or`, and `not`
#
# Backend validation often needs more than one check at the same time.
#
# | Idea | Python | SFI backend meaning |
# | --- | --- | --- |
# | both must be true | `and` | product name **and** spec number are present |
# | at least one is true | `or` | category is Auto Racing **or** Drag Racing |
# | reverse true/false | `not` | record is **not** a duplicate |

# %%
# CODE_RUNNER: Tech Talk 2 - Combine SFI Backend Checks

has_product_name = True
has_spec_number = True
duplicate_spec = False

print("Required fields present:", has_product_name and has_spec_number)
print("At least one field present:", has_product_name or has_spec_number)
print("Spec is new:", not duplicate_spec)

# %% [markdown]
# ### Tech Talk 3: Build a Compound SFI Rule
#
# A backend rule becomes more useful when several Boolean checks are combined into one expression.

# %%
# CODE_RUNNER: Tech Talk 3 - SFI Record Validation

has_product_name = True
has_spec_number = True
valid_category = True
duplicate_spec = False

basic_record_is_valid = (
    has_product_name
    and has_spec_number
    and valid_category
    and not duplicate_spec
)

print("Basic SFI record is valid:", basic_record_is_valid)

# %% [markdown]
# ### Tech Talk 4: Booleans Control Backend Decisions
#
# An `if` statement can use a Boolean result to decide whether the backend should return or reject an SFI part record.

# %%
# CODE_RUNNER: Tech Talk 4 - SFI Backend Decision

part_in_database = True
record_archived = False

can_return_record = part_in_database and not record_archived

if can_return_record:
    print("Return the SFI part record")
else:
    print("Do not return the SFI part record")

# %% [markdown]
# ---
#
# ## 3. Popcorn Hacks & Practice Tasks
#
# > **SFI car/backend build:** These four hacks use automotive SFI data from the project backend: `product_name`, `category`, `spec_number`, and `effective_date`. The challenges become more complex as you move from one record to full backend validation.
#
# ### Popcorn Hack 1: Check One SFI Part Record
#
# An SFI automotive record should be considered complete when it has a product name, a racing category, a spec number, and an effective date.
#
# For this challenge, **Auto Racing** and **Drag Racing** are valid racing categories. Your finished runner should report the Boolean state of each requirement for the record below.

# %%
# CODE_RUNNER: Popcorn Hack 1 - Check SFI Part Fields

part = {
    "product_name": "Replacement Flywheels and Clutch Assemblies",
    "category": "Auto Racing",
    "spec_number": "1.1",
    "effective_date": "Nov. 9, 2001"
}

valid_categories = ["Auto Racing", "Drag Racing"]

# Build and test your solution below.

# %% [markdown]
# ### Popcorn Hack 2: Backend Create Rule
#
# The backend receives the same SFI part record from Hack 1. A new database record should only be created when all required fields are valid and its spec number is not already stored.
#
# The starter runner contains the individual Boolean checks and a `duplicate_spec` value. Build the final create decision so the output correctly accepts or rejects the record.

# %%
# CODE_RUNNER: Popcorn Hack 2 - Backend Create Rule

part = {
    "product_name": "Replacement Flywheels and Clutch Assemblies",
    "category": "Auto Racing",
    "spec_number": "1.1",
    "effective_date": "Nov. 9, 2001"
}

valid_categories = ["Auto Racing", "Drag Racing"]
existing_spec_numbers = ["1.1", "2.1"]

# Build and test your solution below.

# %% [markdown]
# ### Popcorn Hack 3: SFI Search Filter
#
# An SFI backend search can match a record through either its product name or its exact spec number. Search results should only include records from the accepted racing categories.
#
# Use the provided records and query to make the backend return only valid matches. Your solution should still behave correctly when the query or record data changes.

# %%
# CODE_RUNNER: Popcorn Hack 3 - SFI Search Filter

query = "1.2"

records = [
    {
        "product_name": "Replacement Flywheels and Clutch Assemblies",
        "category": "Auto Racing",
        "spec_number": "1.1"
    },
    {
        "product_name": "Multiple Disc Clutch Assemblies",
        "category": "Drag Racing",
        "spec_number": "1.2"
    },
    {
        "product_name": "Racing Flywheel Record",
        "category": "Auto Racing",
        "spec_number": "2.1"
    }
]

valid_categories = ["Auto Racing", "Drag Racing"]

# Build and test your solution below.

# %% [markdown]
# ### Popcorn Hack 4 / Homework: SFI Backend Validator
#
# Build a reusable validator for candidate SFI automotive records.
#
# A valid record has a non-empty product name, an accepted racing category, a non-empty spec number, an effective date, and a spec number that does not already exist in the backend. The provided test data includes different cases that your validator should distinguish correctly.
#
# Your completed runner should clearly print whether each candidate record is accepted or rejected.

# %%
# CODE_RUNNER: Popcorn Hack 4 / Homework - SFI Backend Validator

existing_spec_numbers = ["1.1", "2.1"]
valid_categories = ["Auto Racing", "Drag Racing"]

test_records = [
    {
        "product_name": "Multiple Disc Clutch Assemblies",
        "category": "Auto Racing",
        "spec_number": "1.2",
        "effective_date": "Feb. 9, 2006"
    },
    {
        "product_name": "Replacement Flywheels",
        "category": "Street Car",
        "spec_number": "3.1",
        "effective_date": "Jan. 1, 2026"
    },
    {
        "product_name": "Existing Flywheel Record",
        "category": "Drag Racing",
        "spec_number": "1.1",
        "effective_date": "Jan. 1, 2026"
    }
]

# Build and test your validator below.

# %% [markdown]
# ---
#
# ## 4. Grading Plan (1 Point Total)
#
# The hacks intentionally increase in difficulty. The portfolio page should contain the completed code, actual runner output, and a short explanation of the Boolean logic.
#
# | Activity | Points | What earns the points |
# | --- | ---: | --- |
# | Popcorn Hack 1 | 0.15 | Correct Boolean checks for the SFI record fields with working output. |
# | Popcorn Hack 2 | 0.20 | A correct backend create decision that handles valid, invalid, and duplicate records. |
# | Popcorn Hack 3 | 0.25 | Search logic that correctly combines query matching with racing-category filtering. |
# | Popcorn Hack 4 / Homework | 0.40 | A reusable SFI record validator that correctly accepts and rejects different backend records. |
# | **Total** | **1.0** | |
#
# ---
#
# ## 5. Lesson Revisions & Feedback Evidence
#
# - The Tech Talks and Popcorn Hacks use one consistent SFI automotive/backend context.
# - Hacks 1–4 form a progressive backend challenge rather than unrelated exercises.
# - The data fields mirror the SFI backend model: product name, category, spec number, and effective date.
# - Every Popcorn Hack keeps only the basic SFI starter data in the runner; students write the actual Boolean/backend logic themselves.
# - Popcorn prompts describe the backend requirement without giving students a step-by-step solution.
#
# ---
#
# ## 6. Submit Assignment
#
# Put your completed work on **your own published portfolio/blog page** so your answers are recorded outside this lesson.
#
# Include a section for each Popcorn Hack with your completed code, actual output, and a short explanation of your result.
#
# **Submission steps:**
# - Commit and push the portfolio/blog page.
# - Open the **published page** in your browser and confirm it loads.
# - Copy the full published URL, not the GitHub editor/repository URL.
# - Paste that URL into the built-in **Link Submission** form directly below this lesson.
# - In the description, write: `3.05 Boolean SFI backend hacks 1-4 complete`.
