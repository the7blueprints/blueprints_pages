# %% [markdown]
# ---
# layout: post
# courses: { csa: {week: 3} }
# categories: [Java, Program-Design-Impact]
# lesson_language: Java
# lesson_topic: Program-Design-Impact
# lesson_part: reference
# lesson_type: lesson
# toc: true
# title: Impact of Program Design
# menu: nav/csa_units/csaunit3.html
# permalink: /csa/unit_03/3_2
# ---
