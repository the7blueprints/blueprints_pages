# %% [markdown]
# ---
# layout: post
# courses: { csa: {week: 2} }
# categories: [Java, Selection-and-Iteration-Algorithms]
# lesson_language: Java
# lesson_topic: Selection-and-Iteration-Algorithms
# lesson_part: interactive
# lesson_type: lesson
# toc: true
# title: Implementing Selection and Iteration Algorithms
# menu: nav/csa_units/csaunit2.html
# permalink: /csa/unit_02/2_9
# ---
