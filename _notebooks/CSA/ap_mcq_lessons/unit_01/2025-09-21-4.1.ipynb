# %% [markdown]
# ---
# layout: post
# courses: { csa: {week: 4} }
# categories: [Java, Data-Collection-Ethics]
# lesson_language: Java
# lesson_topic: Data-Collection-Ethics
# lesson_part: reference
# lesson_type: lesson
# toc: true
# title: Ethical and Social Issues Around Data Collection
# menu: nav/csa_units/csaunit4.html
# permalink: /csa/unit_04/4_1
# ---
