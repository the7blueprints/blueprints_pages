# %% [markdown]
# ---
# layout: post
# courses: { csa: {week: 4} }
# categories: [Java, Array-Algorithms]
# lesson_language: Java
# lesson_topic: Array-Algorithms
# lesson_part: interactive
# lesson_type: lesson
# toc: true
# title: Implementing Array Algorithms
# menu: nav/csa_units/csaunit4.html
# permalink: /csa/unit_04/4_5
# ---
