# %% [markdown]
# ---
# layout: post
# courses: { csa: {week: 4} }
# categories: [Java, Wrapper-Classes]
# lesson_language: Java
# lesson_topic: Wrapper-Classes
# lesson_part: interactive
# lesson_type: lesson
# toc: true
# title: Wrapper Classes
# menu: nav/csa_units/csaunit4.html
# permalink: /csa/unit_04/4_7
# ---
